# %% [markdown]
# **Vamos experimentar agora o algoritmo Naive Bayes?**

# %%
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.naive_bayes import GaussianNB

# %%
import pickle
with open('/content/sample_data/titanic.pkl', 'rb') as f:
  X_treino, X_teste, y_treino, y_teste = pickle.load(f)

# %%
modelo = GaussianNB()

# %%
modelo.fit(X_treino, y_treino)
# Out:
# GaussianNB()

# %% [markdown]
# > **Vamos testar o modelo?**

# %%
previsoes = modelo.predict(X_teste)

# %%
previsoes
# Out:
# array(['morreu', 'morreu', 'morreu', 'nao morreu', 'nao morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'nao morreu', 'nao morreu',
#        'nao morreu', 'morreu', 'morreu', 'morreu', 'morreu', 'nao morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'nao morreu', 'morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'morreu', 'morreu',
#        'nao morreu', 'morreu', 'morreu', 'nao morreu', 'morreu',
#        'nao morreu', 'morreu', 'nao morreu', 'morreu', 'morreu', 'morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'morreu', 'morreu', 'morreu',
#        'morreu', 'nao morreu', 'morreu', 'morreu', 'morreu', 'morreu',
#        'nao morreu', 'nao morreu', 'nao morreu', 'morreu', 'nao morreu',
#        'morreu', 'nao morreu', 'morreu', 'nao morreu', 'nao morreu',
#        'nao morreu', 'morreu', 'nao morreu', 'nao morreu', 'morreu',
#        'morreu', 'nao morreu', 'morreu', 'morreu', 'morreu', 'nao morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'nao morreu', 'morreu',
#        'morreu', 'nao morreu', 'nao morreu', 'nao morreu', 'nao morreu',
#        'morreu', 'nao morreu', 'nao morreu', 'morreu', 'nao morreu',
#        'nao morreu', 'nao morreu', 'nao morreu', 'nao morreu', 'morreu',
#        'morreu', 'morreu', 'nao morreu', 'morreu', 'morreu', 'morreu',
#        'nao morreu', 'morreu', 'nao morreu', 'morreu', 'nao morreu',
#        'morreu', 'nao morreu', 'morreu', 'morreu', 'morreu', 'nao morreu',
#        'nao morreu', 'morreu', 'nao morreu', 'nao morreu', 'morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'morreu', 'nao morreu',
#        'morreu', 'nao morreu', 'nao morreu', 'morreu', 'nao morreu',
#        'nao morreu', 'morreu', 'morreu', 'nao morreu', 'nao morreu',
#        'morreu', 'nao morreu', 'morreu', 'nao morreu', 'morreu', 'morreu',
#        'nao morreu', 'nao morreu', 'nao morreu', 'nao morreu', 'morreu',
#        'morreu', 'nao morreu', 'morreu', 'nao morreu', 'morreu', 'morreu',
#        'morreu', 'nao morreu', 'morreu', 'morreu', 'nao morreu', 'morreu',
#        'morreu', 'morreu', 'morreu', 'nao morreu', 'morreu', 'morreu',
#        'morreu', 'nao morreu', 'nao morreu', 'nao morreu', 'morreu',
#        'morreu', 'morreu', 'nao morreu', 'morreu', 'nao morreu', 'morreu',
#        'nao morreu', 'morreu', 'morreu', 'nao morreu', 'nao morreu',
#        'nao morreu', 'nao morreu', 'morreu', 'morreu', 'morreu',
#        'nao morreu', 'nao morreu'], dtype='<U10')

# %% [markdown]
# > **Será se o modelo acertou?**

# %%
y_teste
# Out:
# 709    nao morreu
# 439        morreu
# 840        morreu
# 720    nao morreu
# 39     nao morreu
#           ...
# 433        morreu
# 773        morreu
# 25     nao morreu
# 84     nao morreu
# 10     nao morreu
# Name: Survived, Length: 179, dtype: object

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_teste,previsoes)
# Out:
# 0.7821229050279329

# %%
from yellowbrick.classifier import ConfusionMatrix
confusion_matrix(y_teste, previsoes)
# Out:
# array([[79, 26],
#        [13, 61]])

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_teste, y_teste)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# 0.7821229050279329

# %%
print(classification_report(y_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#       morreu       0.86      0.75      0.80       105
#   nao morreu       0.70      0.82      0.76        74
#
#     accuracy                           0.78       179
#    macro avg       0.78      0.79      0.78       179
# weighted avg       0.79      0.78      0.78       179
